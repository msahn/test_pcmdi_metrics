# %% [markdown]
# # Read data (nc file)

# %%
import cdms2 as cdms

var = 'pr'
data = 'GPCP-2-3'
period = '197901-201907'
ver = 'v20200421'

dir = '/p/user_pub/PCMDIobs/PCMDIobs2_clims/atmos/'+var+'/'+data+'/'
nc = var+'_mon_'+data+'_BE_gn_'+period+'.'+ver+'.AC.nc'
f = cdms.open(dir+nc)
d = f[var]
print(d.shape)
# Out:
# (12, 72, 144)

# %% [markdown]
# # Plot data with basemap

# %%
from class_PlotBaseMap import PlotBaseMap

PlotBaseMap(d[0])
# PlotBaseMap(d[0], vmin='0', vmax='0.0003')

# %%
# !jupyter nbconvert --to script plot_basemap.ipynb
# Out:
# [NbConvertApp] Converting notebook plot_basemap.ipynb to script
# [NbConvertApp] Writing 577 bytes to plot_basemap.py
